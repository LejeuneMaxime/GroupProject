# %%
from IPython.display import display
import json
import pandas as pd
pd.options.display.max_columns = None # Display all columns of a dataframe
pd.options.display.max_rows = 700
from pprint import pprint
import time
import os
from selenium import webdriver
import re
import requests
from bs4 import BeautifulSoup

# %%
import time
import os
from selenium import webdriver
from bs4 import BeautifulSoup

path = "C:Users/User/Documents/HEC/2022-2023/DM/Project"
driver = webdriver.Chrome(executable_path=os.path.join(path, 'chromedriver'))
restaurants_infos = []
url = "https://www.trouvetonresto.be/restaurant/bruxelles"
driver.get(url)
time.sleep(5)

soup = BeautifulSoup(driver.page_source, 'html.parser')

restaurants = soup.find('div', class_='col-md-8 col-sm-7 list-content').find('div', class_='list-restaurant').find_all('div', class_='col-md-6 list-item')

for restaurant in restaurants:
    restaurant_url = restaurant.find('a')['href']
    driver.get(restaurant_url)
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    try:
        restaurant_name = soup.find('div', class_='fiche-header-name').find('h1').text.strip()
    except:
        restaurant_name = "Not available"
        
    try:
        input_element = soup.find(id="input-rating-header")
        rating_value = input_element['value']
    except:
        rating_value = "Not available"
        
    try:
        restaurant_type = soup.find('div', class_='fiche-header-tags').find('strong').text.strip()
    except:
        restaurant_type = "Not available"
        
    try:
        restaurant_address = soup.find('div', class_='sidebar-address sidebar-item').find('address').text.strip().split('\n')
    except:
        restaurant_address = "Not available"

        
    try:
        info1_title = soup.find('div', class_='moreInfo-title').text.strip()
    except:
        info1_title = "Not available"
        
    try:
        info1_value = soup.find('div', class_='moreInfo-value').text.strip()
    except:
        info1_value = "Not available"
        
    try:
        info2_title = soup.find('div', class_='moreInfo-title').find_next_sibling("div").text.strip()
    except:
        info2_title = "Not available"
        
    try:
        info2_value = soup.find('div', class_='moreInfo-value').find_next_sibling("div").text.strip()
    except:
        info2_value = "Not available"
  
  

    restaurants_infos.append({
        'Name': restaurant_name,
        'Rating': rating_value,
        'Type' : restaurant_type,
        'Address': restaurant_address,
        'Info1 titre':  info1_title,
        'Info1 valeur': info1_value,
        'Info2 titre':  info2_title,
        'Info2 valeur': info2_value
        
    })
    

    if len(restaurants_infos) >= 5:
        break

driver.quit()

print(restaurants_infos)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12580\335459247.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path=os.path.join(path, 'chromedriver'))
# [{'Name': "L'Atelier d'Alessandro", 'Rating': '5', 'Type': 'Italien', 'Address': ['Rue Stevin, 54', '                1000 Bruxelles'], 'Info1 titre': 'Origines de la cuisine', 'Info1 valeur': 'Italienne', 'Info2 titre': 'Italienne', 'Info2 valeur': 'Not available'}, {'Name': 'Per Bacco', 'Rating': 'Not available', 'Type': 'Italien', 'Address': ["Rue de l'Enseignement, 31", '                1000 Bruxelles'], 'Info1 titre': 'Capacité maximum', 'Info1 valeur': '40', 'Info2 titre': '40', 'Info2 valeur': 'Not available'}]

# %%
path = "C:Users/flori/Desktop/Master 1/Q2/Data Management"
driver = webdriver.Chrome(executable_path=os.path.join(path, 'chromedriver'))
attractions_infos2 = []
url = "https://www.365.be/fr/recherche/?category=1063&range=150"
driver.get(url)
time.sleep(5)

soup = BeautifulSoup(driver.page_source, 'html.parser')

events = soup.find('div', class_='main-content__body').find('div', class_='row cards').find_all('article', class_='col-12 col-md-6 col-lg-6 col-xl-4')

for event in events:
    full_event_url = f"https://www.365.be{event.find('a')['href']}"
    driver.get(full_event_url)
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    try:
        attraction_name = soup.find('h1', class_="attraction-name").text.strip()
    except:
        attraction_name = "Not available"
    try:
        attraction_type = "natural"
    except:
        attraction_type = "Not available"
    try:
        city_name = soup.find('span', {'itemprop': 'addressLocality'}).text.strip()
    except:
        city_name = "Not available"
    try:
        price_label = soup.find("span", class_="label", text="Prix").find_next_sibling("div").text.strip()
    except:
        price_label = "Not available"
    try:
        visiting_time_label = soup.find("span", class_="label", text="Durée de la visite").find_next_sibling("div").text.strip()
    except:
        visiting_time_label = "Not Available"
    attractions_infos2.append({'Name' : attraction_name,'Type': attraction_type, 'City' : city_name, 'Price' : price_label, 'Visiting time' : visiting_time_label})
print(attractions_infos2)
driver.quit()
